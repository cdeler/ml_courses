# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

# %config InlineBackend.figure_format = 'svg'

# %%
df = pd.read_csv('../data/classification.csv')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
acc = accuracy_score(df['true'], df['pred'])
prec = precision_score(df['true'], df['pred'])
recall = recall_score(df['true'], df['pred'])
f1 = f1_score(df['true'], df['pred'])
print(f'Task 2 : {acc} {prec} {recall} {f1}')
# Out:
# Task 2 : 0.535 0.5584415584415584 0.4215686274509804 0.48044692737430167

# %%
# TP, FP, FN и TN
TP = df[(df['true'] == 1) & (df['pred'] == 1)]
FP = df[(df['true'] == 0) & (df['pred'] == 1)]
FN = df[(df['true'] == 1) & (df['pred'] == 0)]
TN = df[(df['true'] == 0) & (df['pred'] == 0)]
print(f'Task 1 : {len(TP)} {len(FP)} {len(FN)} {len(TN)}')
# Out:
# Task 1 : 43 34 59 64

# %%
df2 = pd.read_csv('../data/scores.csv')

# %%
from sklearn.metrics import roc_auc_score

# %%
df2.head()
# Out:
#    true  score_logreg  score_svm  score_knn  score_tree
# 0     0      0.683832   0.145976   0.787063    0.500000
# 1     1      0.801966   0.239511   1.000000    0.833333
# 2     0      0.382315  -0.245701   0.000000    0.000000
# 3     1      0.506797  -0.137058   0.000000    0.105263
# 4     1      0.488781  -0.154148   0.000000    0.105263

# %%
print('Task 3')
for col_name in ('score_logreg', 'score_svm', 'score_knn', 'score_tree'):
    val = roc_auc_score(df2['true'], df2[col_name])
    print(f'ROC-AUC {col_name} is {val}')
# Out:
# Task 3
# ROC-AUC score_logreg is 0.719187675070028
# ROC-AUC score_svm is 0.7086834733893557
# ROC-AUC score_knn is 0.6351540616246498
# ROC-AUC score_tree is 0.6919267707082833

# %%
from sklearn.metrics import precision_recall_curve

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = []
for col_name in ('score_logreg', 'score_svm', 'score_knn', 'score_tree'):
    prec, recall, thresholds = precision_recall_curve(df2['true'], df2[col_name])
    trace = go.Scatter(x=recall, y=prec, name=col_name)
    data.append(trace)

layout = {'title': 'Precision Recall Curves'}
fig = go.Figure(data=data, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div id="e5cda71e-b631-4b21-95d3-1fce3386d238" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e5cda71e-b631-4b21-95d3-1fce3386d238", [{"name": "score_logreg", "x": [1.0, 0.9897959183673469, 0.9795918367346939, 0.9795918367346939, 0.9795918367346939, 0.9693877551020408, 0.9693877551020408, 0.9591836734693877, 0.9591836734693877, 0.9591836734693877, 0.9591836734693877, 0.9489795918367347, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9387755102040817, 0.9285714285714286, 0.9285714285714286, 0.9285714285714286, 0.9285714285714286, 0.9285714285714286, 0.9285714285714286
# ...
